# %% [markdown]
# # Analysis for Continuous Improvement
#
# Author Name: Meila Madyun
#
# 9-digit PID: 730307805
#
# Continuous Improvement embraces a belief there is _always room to make things better_. It is a mindset and process we value and practice in this course. In this assignment, you are able to practice continuous improvement and contribute to the design ideas of the course.
#
# ## Brainstorming Ideas
#
# Reflect on your personal experiences and observations in COMP110 and **brainstorm modifications to the course that _create value_ beyond its current design**. When brainstorming, try not to be critical of the ideas you come up with regarding scale, stakeholders impacted, or for any other reasons. In the markdown cell below, brainstorm 3 to 5 ideas you think would create value for you.
#
# Each brainstormed idea should state a. the suggested change or addition, b. what the expected value created, and c. which specific stakeholders would benefit.  If helpful, expand on the following template "The course should (state idea here) because it will (state value created here) for (insert stakeholders here)."
#
# Example A: "The course should use only examples from psychology experiments because it will be more relevant for students who are psychology majors."
#
# Example B: "The course should not have post-lesson questions because they are not useful for most students in the class."

# %% [markdown]
# ### Part 1. Creative Ideation
#
# 1. The course should offer group projects, or opportunities to work in groups on conceptual assignments, so that students can benefit from talking through the concepts with their peers.
# 2. The course should follow the flipped-class structure so that students have all of class time to practice course material, and that will benefit students' performance.
# 3. The course should offer more optional practice problems and opportunities to practice, outside of practice quizzes, because it would help students prepare themselves better.
# 4. Students should turn in their personal notes as part of their lessons/participation grade because students will be encouraged to take notes, which will benefit them while taking this class.
# 5. The course should offer more tutoring opportunities because it is helpful to students and should be made more accessible.

# %% [markdown]
# ## Connecting with Available Data
#
# The data you have available for this analysis is limited to the anonymized course survey you and your peers filled out a few weeks ago. The data is found in the `survey.csv` file in this exercise directory. Each row represents an individual survey response. Each column has a description which can be found on the project write-up here: <https://22s.comp110.com/exercises/ex08.html>
#
# Review the list of available data and identify which one of your ideas _does not_, or is _least likely to_, have relevant data to support the analysis of your idea to create value. In the box below, identify which of your ideas lacks data and suggest how we might be able to collect this data in the future. One aspect of _continuous improvement_ is trying to avoid "tunnel vision" where possible improvements are not considered because there is no data available to analyze it. Identifying new data sources can unlock improvements!

# %% [markdown]
# ### Part 2. Identifying Missing Data
#
# 1. Idea without sufficient data to analyze: My first idea about more group work being implemented into the class being beneficial to the students in the class is least likely to be supported by the data in the survey, as well as my idea about offering more practice opportunities. Nowhere in the survey are participants asked about if they feel that they get enough practice, or if they'd benefit from being able to talk out concepts with their peers outside of class examples.
#
# 2. Suggestion for how to collect data to support this idea in the future: I think this idea could be supported in the future if there are questions in the student survey that ask about whether students feel that they get adequate opportunities to practice the content and feel prepared for tests/quizes when they arise, in addition to asking if they think group work would be beneficial.

# %% [markdown]
# ## Choosing an Idea to Analyze
#
# Consider those of your ideas which _do_ seem likely to have relevant data to analyze. If none of your ideas do, spend a few minutes and brainstorm another idea or two with the added connection of data available on hand and add those ideas to your brainstormed ideas list.
#
# Select the one idea which you believe is _most valuable_ to analyze relative to the others and has data to support the analysis of. In the markdown cell for Part 3 below, identify the idea you are exploring and articulate why you believe it is most valuable (e.g. widest impact, biggest opportunity for improvement, simplest change for significant improvement, and so on).

# %% [markdown]
# ### Part 3. Choosing Your Analysis
#
# 1. Idea to analyze with available data: Offering more tutoring opportunities.
#
# 2. This idea is more valuable than the others brainstormed because: Right now there are a lot of office hours offered for exercise help (which is greatly needed and appreciated) that offer short periods of time to fix coding questions, but it would likely be beneficial to extend tutoring hours as well to help target conceptual issues that require more time and practice to master. Creating your own notes may be helpful, but being able to get extra one-on-one attention even when you've written your own notes is beneficial. Having both class periods be synchronous also has the potential to be helpful, but the additional help outside of the classroom would still be likely to benefit students in the class.

# %% [markdown]
# ## Your Analysis
#
# Before you begin analysis, a reminder that we do not expect the data to support everyone's ideas and you can complete this exercise for full credit even if the data does not clearly support your suggestion or even completely refutes it. What we are looking for is a logical attempt to explore the data using the techniques you have learned up until now in a way that _either_ supports, refutes, or does not have a clear result and then to reflect on your findings after the analysis.
#
# Using the utility functions you created for the previous exercise, you will continue with your analysis in the following part. Before you begin, refer to the rubric on the technical expectations of this section in the exercise write-up.
#
# In this section, you are expected to interleave code and markdown cells such that for each step of your analysis you are starting with an English description of what you are planning to do next in a markdown cell, followed by a Python cell that performs that step of the analysis.

# %% [markdown]
# ### Part 4. Analysis
#
# We begin by changing some settings in the notebook to automatically reload changes to imported files.

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# We continue by importing the helper functions from `data_utils`.

# %%
from data_utils import read_csv_rows, head, columnar, select, count

# %% [markdown]
# In this code block, I'm simply importing all of the functions that are required of me to import and use in this exercise, so that they're all here.

# %% [markdown]
# Next, ... (you take it from here and add additional code and markdown cells to read in the CSV file and process it as needed)

# %%
SURVEY_DATA_CSV_FILE_PATH: str = "../../data/survey.csv"

# %%
data_rows: list[dict[str, str]] = read_csv_rows(SURVEY_DATA_CSV_FILE_PATH)

print(f"Confirmation -- Data File Read: {SURVEY_DATA_CSV_FILE_PATH}")
# Out:
# Confirmation -- Data File Read: ../../data/survey.csv

# %% [markdown]
# I needed to use `read_csv_rows` as the first step in my analysis in order to read the survey information into a list of rows that I can use in later functions for my analysis.

# %%
data_cols: dict[str, list[str]] = columnar(data_rows)

print(f"There are {len(data_rows[0].keys())} columns, and there names are: {data_cols.keys()}")
# Out:
# There are 35 columns, and there names are: dict_keys(['row', 'year', 'unc_status', 'comp_major', 'primary_major', 'data_science', 'prereqs', 'prior_exp', 'ap_principles', 'ap_a', 'other_comp', 'prior_time', 'languages', 'hours_online_social', 'hours_online_work', 'lesson_time', 'sync_perf', 'all_sync', 'flipped_class', 'no_hybrid', 'own_notes', 'own_examples', 'oh_visits', 'ls_effective', 'lsqs_effective', 'programming_effective', 'qz_effective', 'oh_effective', 'tutoring_effective', 'pace', 'difficulty', 'understanding', 'interesting', 'valuable', 'would_recommend'])

# %% [markdown]
# I implemented this `columnar` function here to print out all of the column names in the survey, so that I can see all of the column names (in addition to how many columns there are numerically) in order to evaluate which column's data I can utilize for my analysis.

# %%
# TODO: Still need to use head, count, and select, AND ONE FUNCTION OF MY OWN

# %% [markdown]
# ultimately, I want to use the head function for what? Idk. I guess to just print out the entire table... The select function will be used to select for the tutoring_effective column because that's the only one I really care about for this analysis. The count function will be used to count how many people voted for each level of helpfulness of tutoring. The additional function will somehow be used to visualize this data into a graph or something so that we can see if the students actually think this will be helpful or not.

# %%
selected_data: dict[str, list[str]] = select(data_cols, ["tutoring_effective"])

from tabulate import tabulate

tabulate(head(selected_data, 620), selected_data.keys(), "html")
# Out:
# '<table>\n<thead>\n<tr><th>tutoring_effective  </th></tr>\n</thead>\n<tbody>\n<tr><td>                    </td></tr>\n<tr><td>6                   </td></tr>\n<tr><td>                    </td></tr>\n<tr><td>4                   </td></tr>\n<tr><td>3                   </td></tr>\n<tr><td>                    </td></tr>\n<tr><td>4                   </td></tr>\n<tr><td>                    </td></tr>\n<tr><td>7                   </td></tr>\n<tr><td>                    </td></tr>\n<tr><td>7                   </td></tr>\n<tr><td>                    </td></tr>\n<tr><td>                    </td></tr>\n<tr><td>                    </td></tr>\n<tr><td>                    </td></tr>\n<tr><td>7                   </td></tr>\n<tr><td>                    </td></tr>\n<tr><td>4                   </td></tr>\n<tr><td>6                   </td></tr>\n<tr><td>                    </td></tr>\n<tr><td>7                   </td></tr>\n<tr><td>                    </td></tr>\n<tr><td>                    </td></tr>\n
# ...

# %% [markdown]
# In this code cell, I implemented both the `head` and the `select` functions (as well as the `tabulate` feature to make it look pretty) in order to print out a table of the survey results of all students from the tutoring question only.

# %%
data_counts: dict[str, int] = count(selected_data["tutoring_effective"])

print(f"Tutoring effectiveness on a scale from 1 to 7: {data_counts}")
# Out:
# Tutoring effectiveness on a scale from 1 to 7: {'': 365, '6': 40, '4': 92, '3': 11, '7': 62, '5': 44, '1': 3, '2': 3}

# %% [markdown]
# I used the `data_counts` function here to count the frequencies of the 1-7 scale for tutoring effectiveness.

# %%
# TODO: Figure out a function that will allow me to sort that output into an order that makes sense -_-

# %%
from matplotlib import pyplot

pyplot.title("Responses on effectiveness of tutoring.")
pyplot.xlabel("Effectiveness")
pyplot.ylabel("Frequencies")

lables: list[str] = list(data_counts.keys())

values: list[int] = list(data_counts.values())

pyplot.bar(lables, values)
# Out:
# <BarContainer object of 8 artists>

# %% [markdown]
# I used this code block to visualize the responses to the effectiveness of tutoring in a graph, using the matplotlib function Kris showed us for the last exercise.

# %% [markdown]
# ## Conclusion
#
# In the following markdown cell, write a reflective conclusion given the analysis you performed and identify recommendations.
#
# If your analysis of the data supports your idea, state your recommendation for the change and summarize the data analysys results you found which support it. Additionally, describe any extensions or refinements to this idea which might be explored further. Finally, discuss the potential costs, trade-offs, or stakeholders who may be negatively impacted by this proposed change.
#
# If your analysis of the data is inconclusive, summarize why your data analysis results were inconclusive in the support of your idea. Additionally, describe what experimental idea implementation or additional data collection might help build more confidence in assessing your idea. Finally, discuss the potential costs, trade-offs, or stakeholders who may be negatively impacted by experimenting with your idea.
#
# Finally, if your analysis of the data does not support it, summarize your data analysis results and why it refutes your idea. Discuss the potential costs, trade-offs, or stakeholders who may be negatively impacted by this proposed change. If you disagree with the validity of the findings, describe why your idea still makes sense to implement and what alternative data would better support it. If you agree with the validity of the data analysis, describe what alternate ideas or extensions you would explore instead.

# %% [markdown]
# ### Part 5. Conclusion

# %% [markdown]
# This semester we have over 20 hours a week dedicated to office hours, but about 8 hours a week dedicated to tutoring in this course. My idea was to increase the number of office hours per week (not necessarily to 20 hours a week) so that students would have more opportunities to get one-on-one help with concepts, practice problems, and things of that nature without the constraints that exist in office hours. According to my analysis, it's unclear if this would actually benefit students and not negatively impact the other people involved in the process, such as the TAs who sign up to help students during tutoring. Of the 255 students who responded to the 'tutoring effectiveness' question on the survey, 17 people voted 1-3 (which I will consider not effective), 92 people voted 4 (which I'll consider neutral), and 146 people voted 5-7 (which I will consider effective). In this view, more people thought that tutoring was effective than not. The grey area here is that there are 365 students that *didn't* respond to the question. I can only assume that these students didn't answer because it didn't apply to them, which means they didn't go to tutoring and were therefore unable to attest to its effectiveness. Following this reasoning, it wouldn't make sense to increase tutoring hours when more than half of the class doesn't go in the first place. This would be a waste of resources, a waste of time of the TAs and professors that'd have to organize these tutoring hours, and wouldn't benefit students any more than they are currently. Since my initial idea likely wouldn't have a good payoff, I would explore my second-best idea given the data we have of following a flipped-classroom structure.
